# %% [markdown]
# ## 1. Define una variable y una constante.

# %%
variable = 3
CONSTANTE = "hola"

# %% [markdown]
# ## 2. Crea una cadena de texto corta y muéstrala por pantalla.

# %%
"Hola que tal?"
# Out:
# 'Hola que tal?'

# %% [markdown]
# ## 3. Crea una cadena de texto larga y muéstrala por pantalla.

# %%
""" Hola sabes que no
me gustan las cadenas de texto largas"""
# Out:
# ' Hola sabes que no\nme gustan las cadenas de texto largas'

# %% [markdown]
# ## 4. Define una cadena de texto y concaténala con un texto. Asocia el resul-tado a una variable y muestra su valor por pantalla.

# %%
x = "cadena de texto a meter"
resultado = x + " sigo la frase" 
print (resultado)
# Out:
# cadena de texto a meter sigo la frase

# %% [markdown]
# ## 5. Define dos cadenas de texto y concaténalas. Asocia el resultado a una variable y muestra su valor por pantalla.

# %%
x ="7"
y = "8"
resultado = x + " o no " + y
print (resultado)
# Out:
# 7 o no 8

# %% [markdown]
# ## 6. Crea una cadena de texto y comprueba su longitud

# %%
texto = " esto es una cadena de texto a probar"
len(texto)
# Out:
# 37

# %% [markdown]
# ## 7. Crea una cadena de texto de mínimo 10 caracteres e indica cuál es el carácter correspondiente a la sexta posición.

# %%
texto = "supercalifragilisticoespialidoso"
texto[6]
# Out:
# 'a'

# %% [markdown]
# ## 8. Utilizando la cadena de texto anterior selecciona una rebanada de cinco caracteres desde una posición en concreto.

# %%
texto = "supercalifragilisticoespialidoso"
texto [2:7]
# Out:
# 'perca'

# %% [markdown]
# ## 9. Utilizando la misma cadena de texto selecciona los caracteres desde la sexta posición hasta el final.

# %%
texto = "supercalifragilisticoespialidoso"
texto[6:]
# Out:
# 'alifragilisticoespialidoso'

# %% [markdown]
# ## 10. Utiliza nuevamente la cadena de texto anterior y cuenta las veces que se repite un carácter en la cadena.

# %%
texto = "supercalifragilisticoespialidoso"
texto.count("a")
# Out:
# 3

# %% [markdown]
# ## 11. Utilizando la misma cadena de texto de ejercicios anteriores divide la cadena tomando el espacio como carácter delimitador.

# %%
texto = "supercali fragilisti coespialidoso"
texto.split()
# Out:
# ['supercali', 'fragilisti', 'coespialidoso']

# %% [markdown]
# ## 12. Repite el ejercicio anterior, pero utilizando otro carácter como delimi-tador.

# %%
texto = "supercali fragilisti coespialidoso"
texto.split("a")
# Out:
# ['superc', 'li fr', 'gilisti coespi', 'lidoso']

# %% [markdown]
# ## 13. Utiliza la asignación múltiple para asignar una variable a cada trozo de la cadena.

# %%
texto = "supercali fragilisti coespialidoso"
texto.split()
primero,segundo, tercero = texto.split()

# %% [markdown]
# ## 14. Crea una cadena de texto formada por una palabra y ponla en mayús-culas.

# %%
texto = "andres"
texto.upper()
# Out:
# 'ANDRES'

# %% [markdown]
# ## 15. Consigue que la cadena de caracteres se guarde en minúsculas dentro de la variable.

# %%
texto = "HELLO"
texto = texto.lower()
print(texto)
# Out:
# hello

# %% [markdown]
# ## 16. Remplaza un carácter de la cadena de texto anterior por otro

# %%
texto = "hello"
texto.replace("e","i")
# Out:
# 'hillo'

# %% [markdown]
# ## 17. Comprueba si la cadena de texto anterior está compuesta por letras. Comprueba también si está compuesta por dígitos.

# %%
texto = "hello"
texto.isalpha()
# Out:
# True

# %%
texto = "hello"
texto.isdigit()
# Out:
# False

# %% [markdown]
# ## 18. Formatea una cadena de texto insertando un valor en la posición mar-cada entre {}

# %%
texto = "seguro?" 
"hello{} this is {} an exercise".format("bullshit", texto)
# Out:
# 'hellobullshit this is seguro? an exercise'
