# %% [markdown]
# ## Ejercicio 1_1_Python

# %% [markdown]
# ### 1. Crea un comentario.

# %%
#Hola que tal

# %% [markdown]
# ### 2. Realiza las siguientes operaciones utilizando números enteros: Una suma, una resta y una multiplicación.

# %%
12+2
# Out:
# 14

# %%
20-5
# Out:
# 15

# %%
15*8
# Out:
# 120

# %% [markdown]
# ### 3. Realiza una división de números enteros cuyo resultado sea un entero.

# %%
10//5
# Out:
# 2

# %% [markdown]
# ### 4. Calcula la potencia de un número entero.

# %%
20**2
# Out:
# 400

# %% [markdown]
# ### 5. Realiza las siguientes operaciones utilizando números decimales o enteros y decimales: Una suma, una resta, una multiplicación y una división.

# %%
12.5+8
# Out:
# 20.5

# %%
2-3.2
# Out:
# -1.2000000000000002

# %%
5.89*7.98
# Out:
# 47.0022

# %%
25.369/4
# Out:
# 6.34225

# %% [markdown]
# ### 6. Calcula el valor absoluto de dos números enteros y de un número decimal.

# %%
abs(-78)
# Out:
# 78

# %%
abs(78)
# Out:
# 78

# %%
abs(-89.78)
# Out:
# 89.78

# %% [markdown]
# ### 7. Calcula el resto de una división.

# %%
81%7
# Out:
# 4

# %% [markdown]
# ### 8. Redondea un número decimal para que sólo tenga cifra decimal. Repite el ejercicio para que tenga hasta dos cifras decimales.

# %%
round(45/89,1)
# Out:
# 0.5

# %%
round(45/89,3)
# Out:
# 0.506

# %% [markdown]
# ### 9. Realiza las siguientes operaciones de comparación utilizando números enteros o decimales: Mayor que; menor que; igual que; no igual que; igual o mayor que; igual o menor que

# %%
65>45.8
# Out:
# True

# %%
78<7
# Out:
# False

# %%
4==4
# Out:
# True

# %%
4!=4
# Out:
# False

# %%
34>=87
# Out:
# False

# %%
532<=56
# Out:
# False

# %% [markdown]
# ### 10. Define una variable y una constante.

# %%
texto = "texto"
NO_TEXTO = "No es texto"
print(texto)
print(NO_TEXTO)
# Out:
# texto
# No es texto

# %% [markdown]
# ### 11. Crea dos variables y comprueba si alguna de ellas tiene el valor "None" asignado.

# %%
texto = "algo"
algo = "texto"
algo is None
# Out:
# False

# %% [markdown]
# ### 12. Define variable e instancia dos variables e intercambia sus valores sin utilizar una intermedia (o auxiliar).

# %%
texto = "algo"
algo = "texto"
nada = "cosas"
cosas = " poco"
texto, algo = nada, cosas
nada, cosas = texto, algo
print(texto)
print(algo)
print(nada)
print(cosas)
# Out:
# cosas
#  poco
# cosas
#  poco

# %% [markdown]
# ### 13. Crea dos variables cuyo valor sea verdadero y falso. Utiliza las variables para realizar las operaciones lógicas habituales (AND y OR).

# %%
texto = False
cosas = True

texto and cosas
# Out:
# False

# %%
texto = False
cosas = True

texto or cosas
# Out:
# True
