# %% [markdown]
# # Cuaderno de ejercicios para realizar actividades con Pandas, StatsModels y Scipy.stats

# %% [markdown]
# Aqui recopilo una serie de ejercicios para practicar el uso de estas librerias, sus logicas y sintaxis.

# %% [markdown]
# ## 1º Cargamos el fichero con el que vamos a trabajar. Cargamos las lbrerias con las que vamos a trabajar. Comprobamos los datos.

# %% [markdown]
# > ***scipy.stats as stats*** es una libreria que nos va a permitir introducir estadisticas en ls graficos de Seaborn

# %%
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
import scipy.stats as stats
import seaborn as sns

Ruta = Path(r"C:\proyecto-faust\M02_Python_Librerias_Big_Data\UX_Material_Extra_Librerias\U10_ejercicios\Auto.csv")
dataset = pd.read_csv(Ruta, sep = ",")
dataset.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
dataset.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.0+ KB

# %% [markdown]
# ## 1º Pregunta: Crea un grafico de distribucion para mpg

# %%
sns.displot(dataset["mpg"])

# %% [markdown]
# ## 2º Pregunta: Crea un grafico de distribucion para peso

# %%
sns.displot(dataset["weight"])

# %% [markdown]
# ## 3º Pregunta: Crea un grafico de distribucion para cv

# %%
sns.displot(dataset["horsepower"])

# %% [markdown]
# ## 4º Pregunta: Completar NaN.s Utilizaremos .fillna() y asignaremos un valor. Volveremos a hacer la grafica de distribucion.

# %%
dataset["horsepower"] = dataset["horsepower"].fillna(dataset["horsepower"].mean())
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    float64
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.0+ KB

# %%
sns.displot(dataset["horsepower"])
